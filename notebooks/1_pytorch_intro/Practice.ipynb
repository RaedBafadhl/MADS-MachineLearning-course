# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(sys.executable)
print("Everything works!")
# Out:
# /home/rbafadhl/MADS-MachineLearning-course/venv/bin/python
# Everything works!
